# %%
#!pip install urllib3
import urllib
import urllib.request

currURL = 'https://raw.githubusercontent.com/StaircaseAPI/translator/master/json-schemas/staircase-v0.json?token=AWEGHV54IRR6MMS5NP23463BUGQOA'
with urllib.request.urlopen(currURL) as f:
    html = f.read().decode('utf-8')

#print(html)
# Out:
# {
#   "$schema": "http://json-schema.org/draft-07/schema",
#   "type": "object",
#   "properties": {
#     "about_versions": {
#       "$ref": "#/definitions/about_versions"
#     },
#     "deal_sets": {
#       "$ref": "#/definitions/deal_sets"
#     },
#     "document_sets": {
#       "$ref": "#/definitions/document_sets"
#     },
#     "relationships": {
#       "$ref": "#/definitions/relationships"
#     },
#     "system_signatures": {
#       "$ref": "#/definitions/system_signatures"
#     },
#     "deal_sets_extra": {
#       "$ref": "#/definitions/deal_sets_extra"
#     },
#     "document_sets_extra": {
#       "$ref": "#/definitions/document_sets_extra"
#     }
#   },
#   "definitions": {
#     "about_versions": {
#       "type": "object",
#       "properties": {
#         "about_version": {
#           "type": "array",
#           "items": {
#             "$ref": "#/definitions/about_version"
#           }
#         }
#       }
#     },
#     "deal": {
#       "type": "object",
#       "properties": {
#         "about_versions": {
#           "$ref": "#/definitions/about_versions"
#         },
#         "assets": {
#           "$ref": "#/definitions/assets",
#           "description": "The total of all assets for all borrowers reported on an instance of the URLA. Collected in Section VI. Assets and Liabilities."
#         },
#         "collaterals": {
#           "$ref": "#/definitions/collaterals",
#           "description": "A collection of assets that will be used as collateral for the loans of this deal or the collateral that has been used for collateral in this deal."
#         },
#         "communication_events": {
#           "$ref": "#/definitions/communication_events",
#           "description": "Information regarding one or more events. Holds all occurrences of COMMUNICATION EVENT."
#         },
#         "deal_comments": {
#           "$ref": "#/definitions/deal_comments",
#           "description": "Information about one or more DEAL_COMMENT. Holds all occurrences of DEAL_COMMENT."
#         },
#         "expenses": {
#           "$ref": "#/definitions/expenses"
#         },
#         "liabilities": {
#           "$ref": "#/definitions/liabilities",
#           "description": "collection of objects that describe the liabilities of borrower parties that were examined to determine credit worthiness"
#         },
#         "litigations": {
#           "$ref": "#/definitions/litigations",
#           "description": "Information about one or more litigations. Holds all occurrences of LITIGATION."
#         },
#         "loans": {
#           "$ref": "#/definitions/loans",
#           "description": "A collection of loans that are part of a single deal"
#         },
#         "parties": {
#           "$ref": "#/definitions/parties",
#           "description": "A collection of objects that define specific parties to a deal. This includes the direct participating parties, such as borrower and seller and the indirect parties such as the credit report provider."
#         },
#         "reference": {
#           "$ref": "#/definitions/reference",
#           "description": "REFERENCE is a pointer to an XML structure that satisfies the XML type required within this context. The referenced structure may exist internally or externally to the document. A REFERENCE is resolved by replacing its parent container with the referenced XML structure."
#         },
#         "relationships": {
#           "$ref": "#/definitions/relationships",
#           "description": "Collection of xlink attributes that define relationships between two elements and optionally provide the type of relationship. Many:Many relationships are formed with multiple RELATIONSHIP children with the same  xlink:title value"
#         },
#         "services": {
#           "$ref": "#/definitions/services",
#           "description": "A collection of objects that describe requests and responses for services."
#         },
#         "supporting_record_sets": {
#           "$ref": "#/definitions/supporting_record_sets",
#           "description": "Information about one or more supporting record sets. Holds all occurrences of SUPPORTING RECORD SET."
#         },
#         "is_facilitate_servicing_reo_purchase": {
#           "type": "boolean",
#           "description": "When true, indicates that this loan or mortgage was made to facilitate the sale of a Servicing REO property."
#         },
#         "is_mortgage_originator_first_time_home_buyer_eligibility": {
#           "type": "boolean",
#           "description": "When true, indicates that the mortgage originator has determined that this deal is eligible to be considered a &#34;First Time Home Buyer.&#34;"
#         },
#         "assets_extra": {
#           "$ref": "#/definitions/assets_extra"
#         },
#         "loans_extra": {
#           "$ref": "#/definitions/loans_extra"
#         },
#         "services_extra": {
#           "$ref": "#/definitions/services_extra"
#         },
#         "liabilities_extra": {
#           "$ref": "#/definitions/liabilities_extra"
#         }
#       },
#       "description": "The root element for all transactions that apply to the use cases of a single deal. A Deal may contain multiple loans or loan applications."
#     },
#     "document": {
#       "type": "object",
#       "properties": {
#         "about_versions": {
#           "$ref": "#/definitions/about_versions"
#         },
#         "audit_trail": {
#           "$ref": "#/definitions/audit_trail",
#           "description": "The AUDIT_TRAIL element holds a history of actions performed on the document."
#         },
#         "deal_sets": {
#           "$ref": "#/definitions/deal_sets"
#         },
#         "document_classification": {
#           "$ref": "#/definitions/document_classification",
#           "description": "Contains information about a specific instance of a document that describes its use (as opposed to its contents)."
#         },
#         "foreign_objects": {
#           "$ref": "#/definitions/foreign_objects"
#         },
#         "map": {
#           "$ref": "#/definitions/map",
#           "description": "The Map Element contains or points to stylesheets for generating or populating document views based on the contents of the DATA and/or SIGNATORY elements. The resulting View is used to replace a View containing outdated data or to verify that the data in the target View matches the data provided in the SIGNATORY and DATA elements."
#         },
#         "reference": {
#           "$ref": "#/definitions/reference",
#           "description": "REFERENCE is a pointer to an XML structure that satisfies the XML type required within this context. The referenced structure may exist internally or externally to the document. A REFERENCE is resolved by replacing its parent container with the referenced XML structure."
#         },
#         "relationships": {
#           "$ref": "#/definitions/relationships",
#           "description": "Collection of xlink attributes that define relationships between two elements and optionally provide the type of relationship. Many:Many relationships are formed with multiple RELATIONSHIP children with the same  xlink:title value"
#         },
#         "signatories": {
#           "$ref": "#/definitions/signatories",
#           "description": "Information about one or more types of signatories. Holds all occurrences of SIGNATORY."
#         },
#         "system_signatures": {
#           "$ref": "#/definitions/system_signatures"
#         },
#         "content": {
#           "$ref": "#/definitions/content"
#         },
#         "views": {
#           "$ref": "#/definitions/views",
#           "description": "The VIEWS element contains a list of VIEW elements."
#         },
#         "deal_sets_extra": {
#           "$ref": "#/definitions/deal_sets_extra"
#         }
#       },
#       "description": "A DOCUMENT element contains or refers to an electronic record that reports one or more aspects of a business transaction. A DOCUMENT element has types, purposes, and uses which are described in the DOCUMENT_CLASSIFICATION element. A DOCUMENT element contains one or more VIEW elements which allow rendering for human consumption, for example on a computer display or printed on paper. A DOCUMENT element may contain a DEAL_SETS element with data related to the DOCUMENT. A DOCUMENT element may also contain a MAP element that relates data in the DOCUMENT to populated fields in one or more VIEW elements. A DOCUMENT may contain SIGNATORY elements used to represent the legally binding signatures of the parties named in the electronic record. A DOCUMENT also supports SYSTEM_SIGNATURE elements to create digital tamper-evident seals over portions or all of the DOCUMENT. Finally, a DOCUMENT may contain one or more AUDIT_TRAIL_ENTRY elements that list events which occurred to the DOCUMENT. A DOCUMENT is also known as a MISMO V3 SMART Doc® electronic document. A DOCUMENT may be delivered within a MISMO V3 MESSAGE, or a DOCUMENT element may be the root element of a standalone resource that may be validated with the model schema."
#     },
#     "loan": {
#       "type": "object",
#       "description": "Information specific to a mortgage loan agreement between one or more borrowers and a mortgage lender.",
#       "properties": {
#         "relationship_id": {
#           "$ref": "#/definitions/relationship_id"
#         },
#         "array_sequence_number": {
#           "$ref": "#/definitions/array_sequence_number"
#         },
#         "ach": {
#           "$ref": "#/definitions/ach",
#           "description": "Information specific to drafting of automatic/regular payment."
#         },
#         "adjustment": {
#           "$ref": "#/definitions/adjustment",
#           "description": "Data specific to the rules for adjustments and conversions to the interest rate and principal and interest payment for the life of the loan as specified in the Note. Includes provisions to capture the modifications to interest rate and principal and interest payment for each adjustment occurrence period. Also specifies the Rules for selecting the appropriate Index upon which the adjustments may be based."
#         },
#         "affordable_lending": {
#           "$ref": "#/definitions/affordable_lending"
#         },
#         "amortization": {
#           "$ref": "#/definitions/amortization"
#         },
#         "assumability": {
#           "$ref": "#/definitions/assumability"
#         },
#         "billing_address": {
#           "$ref": "#/definitions/billing_address"
#         },
#         "buydown": {
#           "$ref": "#/definitions/buydown",
#           "description": "Describes the provision, schedule, and structure of funds used to reduce the interest rate and/or payment on a mortgage note a temporary basis. A permanent buydown is covered by points paid at origination, see Borrower Paid Discount Points Total Amount."
#         },
#         "capitalizations": {
#           "$ref": "#/definitions/capitalizations",
#           "description": "Information about one or more types of capitalization for a loan. Holds all occurrences of CAPITALIZATION."
#         },
#         "charge_off": {
#           "$ref": "#/definitions/charge_off",
#           "description": "Information regarding identification, reason and total amounts charged off on the loan."
#         },
#         "closing_information": {
#           "$ref": "#/definitions/closing_information"
#         },
#         "collections": {
#           "$ref": "#/definitions/collections",
#           "description": "Information about one or more types of collection efforts for a loan. Holds all occurrences of  COLLECTION."
#         },
#         "construction": {
#           "$ref": "#/definitions/construction"
#         },
#         "contract_variances": {
#           "$ref": "#/definitions/contract_variances",
#           "description": "Information about one or more types of contract variances associated with a LOAN. Contains all instances of CONTRACT_VARIANCE."
#         },
#         "credit_enhancements": {
#           "$ref": "#/definitions/credit_enhancements"
#         },
#         "disclosures": {
#           "$ref": "#/definitions/disclosures",
#           "description": "Information about one or more types of disclosure. Holds all occurrences of DISCLOSURE."
#         },
#         "document_specific_data_sets": {
#           "$ref": "#/definitions/document_specific_data_sets",
#           "description": "Data that is not used for anything else except for document preparation AND does not fit well anywhere else under DEAL."
#         },
#         "documentations": {
#           "$ref": "#/definitions/documentations"
#         },
#         "down_payments": {
#           "$ref": "#/definitions/down_payments"
#         },
#         "draw": {
#           "$ref": "#/definitions/draw",
#           "description": "Information on the disbursement of a portion of the loan proceeds to the borrower. This container would be used for a loan with a line of credit or a construction loan."
#         },
#         "escrow": {
#           "$ref": "#/definitions/escrow",
#           "description": "Information specific to funds collected through the loan payment and held to pay expenses such as taxes and insurance or funds held back after closing that are to be used for property improvements or repairs."
#         },
#         "fee_information": {
#           "$ref": "#/definitions/fee_information",
#           "description": "Information concerning fees or costs paid or assessed during the origination, closing, or ongoing servicing of a loan."
#         },
#         "foreclosures": {
#           "$ref": "#/definitions/foreclosures",
#           "description": "Information regarding foreclosure on a loan. Holds all occurrences of FORECLOSURE."
#         },
#         "government_loan": {
#           "$ref": "#/definitions/government_loan"
#         },
#         "heloc": {
#           "$ref": "#/definitions/heloc"
#         },
#         "high_cost_mortgages": {
#           "$ref": "#/definitions/high_cost_mortgages",
#           "description": "Information related to one or more determinations of the transaction as a high cost or higher priced mortgage. Holds all occurrences of HIGH_COST_MORTGAGE."
#         },
#         "hmda_loan": {
#           "$ref": "#/definitions/hmda_loan",
#           "description": "Information used for reporting on a HMDA specific loan."
#         },
#         "housing_expenses": {
#           "$ref": "#/definitions/housing_expenses",
#           "description": "Information regarding one or more types of housing expense. Holds all occurrences of HOUSING_EXPENSE."
#         },
#         "insurance_claims": {
#           "$ref": "#/definitions/insurance_claims",
#           "description": "Information about one or more insurance claims proceeds associated with the loan or subject property. Holds all occurrences of INSURANCE_CLAIM."
#         },
#         "interest_calculation": {
#           "$ref": "#/definitions/interest_calculation"
#         },
#         "interest_only": {
#           "$ref": "#/definitions/interest_only"
#         },
#         "investor_features": {
#           "$ref": "#/definitions/investor_features"
#         },
#         "investor_loan_information": {
#           "$ref": "#/definitions/investor_loan_information",
#           "description": "Data specific to the relationship between the seller and the investor, including the reporting and financial obligations between the seller, the servicer, and the investor. The structure also holds data on the investor's interest in the Delivery Loan."
#         },
#         "late_charge": {
#           "$ref": "#/definitions/late_charge",
#           "description": "Defines the calculation of late charges that apply when a borrower does not make timely payments."
#         },
#         "loan_comments": {
#           "$ref": "#/definitions/loan_comments"
#         },
#         "loan_identifiers": {
#           "$ref": "#/definitions/loan_identifiers",
#           "description": "Collection of current and previous identifiers for this loan"
#         },
#         "loan_level_credit": {
#           "$ref": "#/definitions/loan_level_credit"
#         },
#         "loan_product": {
#           "$ref": "#/definitions/loan_product",
#           "description": "A collection of facts used as descriptors of the characteristics of a financial instrument for sale in the marketplace that an investor is willing to buy."
#         },
#         "loan_programs": {
#           "$ref": "#/definitions/loan_programs"
#         },
#         "loan_state": {
#           "$ref": "#/definitions/loan_state"
#         },
#         "loan_statuses": {
#           "$ref": "#/definitions/loan_statuses"
#         },
#         "ltv": {
#           "$ref": "#/definitions/ltv"
#         },
#         "maturity": {
#           "$ref": "#/definitions/maturity"
#         },
#         "mers_registrations": {
#           "$ref": "#/definitions/mers_registrations"
#         },
#         "mi_data": {
#           "$ref": "#/definitions/mi_data",
#           "description": "Information specific to the mortgage insurance carried by the lender on the loan."
#         },
#         "modifications": {
#           "$ref": "#/definitions/modifications"
#         },
#         "mortgage_scores": {
#           "$ref": "#/definitions/mortgage_scores"
#         },
#         "negative_amortization": {
#           "$ref": "#/definitions/negative_amortization",
#           "description": "Information regarding loans with negative amortization. Negative amortization is unpaid interest added to the mortgage principal. This applies to loans where the principal balance increases because the payments do not cover the interest."
#         },
#         "optional_products": {
#           "$ref": "#/definitions/optional_products"
#         },
#         "origination_funds": {
#           "$ref": "#/definitions/origination_funds"
#         },
#         "origination_systems": {
#           "$ref": "#/definitions/origination_systems"
#         },
#         "payment": {
#           "$ref": "#/definitions/payment",
#           "description": "The total dollar amount per month of the present housing expense type for all borrowers reported on an instance of the URLA. Collected on the URLA in Section V. Present Housing Expense."
#         },
#         "prepayment_penalty": {
#           "$ref": "#/definitions/prepayment_penalty",
#           "description": "The dollar amount of the Prepayment Penalty charged on the account being paid in full."
#         },
#         "purchase_credits": {
#           "$ref": "#/definitions/purchase_credits"
#         },
#         "qualification": {
#           "$ref": "#/definitions/qualification"
#         },
#         "qualified_mortgage": {
#           "$ref": "#/definitions/qualified_mortgage",
#           "description": "Information used to describe and determine Qualified Mortgage loan eligibility."
#         },
#         "refinance": {
#           "$ref": "#/definitions/refinance"
#         },
#         "rehabilitation": {
#           "$ref": "#/definitions/rehabilitation"
#         },
#         "reverse_mortgage": {
#           "$ref": "#/definitions/reverse_mortgage",
#           "description": "Information specific to a reverse mortgage."
#         },
#         "servicing": {
#           "$ref": "#/definitions/servicing",
#           "description": "Loan level information on the servicing of the loan."
#         },
#         "terms_of_loan": {
#           "$ref": "#/definitions/terms_of_loan",
#           "description": "Describes characteristics of the loan, including the behavior defined in the financial instrument."
#         },
#         "treasury_npv": {
#           "$ref": "#/definitions/treasury_npv",
#           "description": "Information about the results and factors associated with the Treasury Net Present Value Test."
#         },
#         "underwriting": {
#           "$ref": "#/definitions/underwriting",
#           "description": "Information about how the loan was underwritten, by whom the loan was underwritten, the underwriting decision, and key parameters influencing that decision."
#         },
#         "workouts": {
#           "$ref": "#/definitions/workouts"
#         },
#         "is_accelerated_payment_program": {
#           "type": "boolean",
#           "description": "Indicates that mortgagor participates in some sort of accelerated principal re-payment program which may be administered by a third party."
#         },
#         "is_ach": {
#           "type": "boolean",
#           "description": "When true, indicates that a loan is enrolled in Automatic Clearing House (ACH) payment drafting."
#         },
#         "is_active_litigation": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan is subject to active litigation."
#         },
#         "application_received_date": {
#           "type": "string",
#           "description": "The date the creditor or originator received the application from the borrower for the subject mortgage loan.",
#           "format": "date"
#         },
#         "is_arms_length": {
#           "type": "boolean",
#           "description": "Indicates that this is an arm's length transaction. An arm's length transaction is between a willing buyer and a willing seller with no undue influence on either party and there is no relationship between the parties except that of the specific transaction."
#         },
#         "is_assumability": {
#           "type": "boolean",
#           "description": "Indicates whether the pool is backed by loans that are assumable by another borrower."
#         },
#         "is_assumed": {
#           "type": "boolean",
#           "description": "Indicates if the loan has been assumed"
#         },
#         "is_balloon_guaranteed_refinancing": {
#           "type": "boolean",
#           "description": "When true, indicates refinancing of the balloon mortgage loan  is guaranteed by the lender."
#         },
#         "is_balloon": {
#           "type": "boolean",
#           "description": "When true, indicates that a final balloon payment is required to fully pay off the loan."
#         },
#         "balloon_payment": {
#           "type": "number",
#           "description": "The dollar amount of the final, or lump sum, balloon payment."
#         },
#         "balloon_payment_maximum": {
#           "type": "number",
#           "description": "The largest scheduled lump sum payment over the life of loan. This applies when there are scheduled lump sum payments that are more than twice as large as the average of earlier scheduled payments."
#         },
#         "balloon_payment_minimum": {
#           "type": "number",
#           "description": "The smallest scheduled lump sum payment over the life of loan. This applies when there are scheduled lump sum payments that are more than twice as large as the average of earlier scheduled payments."
#         },
#         "is_balloon_reset": {
#           "type": "boolean",
#           "description": "When true, indicates that the balloon loan has been reset to the current market rate."
#         },
#         "is_balloon_reset_option": {
#           "type": "boolean",
#           "description": "When true, indicates the balloon loan has an option to reset."
#         },
#         "is_below_market_subordinate_financing": {
#           "type": "boolean",
#           "description": "Indicates whether the seller provided below-market subordinate financing."
#         },
#         "is_biweekly_to_monthly_on_default": {
#           "type": "boolean",
#           "description": "Indicates if the lender allows conversion from Bi-weekly payments to monthly upon a default by the borrower."
#         },
#         "borrower_count": {
#           "type": "integer",
#           "description": "The number of borrowers obligated on the note."
#         },
#         "is_buydown_temporary_subsidy_funding": {
#           "type": "boolean",
#           "description": "When true, indicates that there is buydown funding on this loan that reduces the interest rate and/or the payments for a specified period."
#         },
#         "is_capitalized_fees": {
#           "type": "boolean",
#           "description": "Indicates that the mortgage balance includes capitalized origination fees."
#         },
#         "is_capitalized": {
#           "type": "boolean",
#           "description": "Indicates that interest accrued, escrow disbursements made and/or fees charged are included in the unpaid principal balance."
#         },
#         "is_closing_cost_financed": {
#           "type": "boolean",
#           "description": "Indicates that some or all of the closing cost were financed into the loan amount."
#         },
#         "is_closing_disclosure_waiting_period_waived": {
#           "type": "boolean",
#           "description": "When true, indicates that upon receipt of the Closing Disclosure, and due to a bona fide personal financial emergency, the consumer modified or waived the three-business-day waiting period that must be met prior to consummation of the mortgage loan transaction."
#         },
#         "collateral_pledged_to_name": {
#           "type": "string",
#           "description": "Specifies to whom the loan has been pledged as collateral."
#         },
#         "is_concurrent_origination": {
#           "type": "boolean",
#           "description": "Indicates that a new first mortgage will be closed concurrently with a second or a HELOC loan."
#         },
#         "is_concurrent_origination_lender": {
#           "type": "boolean",
#           "description": "Indicates that a concurrent loan is from the same lender. This is in conjunction with Concurrent Origination Indicator."
#         },
#         "is_conforming": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan amount is a conforming loan amount by Fannie Mae and Freddie Mac standards."
#         },
#         "is_construction": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan is a construction loan."
#         },
#         "is_conversion_of_contract_for_deed": {
#           "type": "boolean",
#           "description": "When true, indicates that the subject transaction proceeds are used to pay off the remaining balance of the land contract (also known as a contract for deed)."
#         },
#         "is_convertible": {
#           "type": "boolean",
#           "description": "Indicates that the loan has a convertible characteristic."
#         },
#         "correspondent_acquisition_type": {
#           "type": "string",
#           "description": "A value from a MISMO prescribed list that specifies the method under which a loan was obtained from a correspondent lender by a security issuer.",
#           "enum": [
#             "Bulk",
#             "Flow",
#             "Other"
#           ]
#         },
#         "correspondent_acquisition_type_other": {
#           "type": "string",
#           "description": "A free-form text field that specifies the enumeration when the value of Other is used for Correspondent Acquisition Type."
#         },
#         "is_credit_enhancement": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan has a credit enhancement."
#         },
#         "creditor_servicing_of_statement_type": {
#           "type": "string",
#           "description": "Specifies the certainty of the originating lender's or creditor's intention to service the mortgage loan.",
#           "enum": [
#             "CreditorIntendsToServiceLoan",
#             "CreditorIntendsToTransferServicingOfLoan",
#             "CreditorMayAssignSellOrTransferServicingOfLoan",
#             "Other"
#           ]
#         },
#         "creditor_servicing_of_statement_type_other": {
#           "type": "string",
#           "description": "A free-form text field used to capture additional information when Other is selected for Creditor Servicing Of Loan Statement Type."
#         },
#         "current_interest_rate_percent": {
#           "type": "number",
#           "description": "The current interest rate, expressed as a percent, for this loan."
#         },
#         "deferred_interest_balance": {
#           "type": "number",
#           "description": "Accrued Uncollected Interest"
#         },
#         "is_delegated_underwriting": {
#           "type": "boolean",
#           "description": "When true, indicates that the underwriting authority on a loan is delegated to the loan originator based on disclosed guidelines."
#         },
#         "is_demand_feature": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan has a demand feature."
#         },
#         "is_eligible_for_lender_paid_mi": {
#           "type": "boolean",
#           "description": "Indicates that the mortgage loan is eligible for lender-paid MI."
#         },
#         "is_employee_program": {
#           "type": "boolean",
#           "description": "Indicates if the loan is part of an employee loan program."
#         },
#         "is_energy_related_improvements": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan will include an amount for energy-related improvements."
#         },
#         "is_e_note_certified": {
#           "type": "boolean",
#           "description": "Indicates whether the loan delivery data has been automatically certified against eNote data."
#         },
#         "is_e_note": {
#           "type": "boolean",
#           "description": "Indicates that an eNote is used as part of this loan."
#         },
#         "escrow_absence_reason_type": {
#           "type": "string",
#           "description": "Specifies the reason the loan does not have an escrow account.",
#           "enum": [
#             "BorrowerDeclined",
#             "LenderDoesNotOffer",
#             "LenderDoesNotRequire",
#             "Other"
#           ]
#         },
#         "escrow_absence_reason_type_other": {
#           "type": "string",
#           "description": "A free-form text field used to collect additional information when Other is selected for Escrow Absence Reason Type."
#         },
#         "escrow_account_lender_requirement_type": {
#           "type": "string",
#           "description": "Identifies the escrow account status in terms of the requirements of the lender in the mortgage loan transaction.",
#           "enum": [
#             "EscrowsRequiredByLender",
#             "EscrowsWaivedByLender"
#           ]
#         },
#         "is_escrow_account_requested": {
#           "type": "boolean",
#           "description": "When true, indicates that the establishment of an escrow account has been requested by the borrower(s) for the loan."
#         },
#         "is_escrow": {
#           "type": "boolean",
#           "description": "Indicates whether or not escrows are associated with this loan."
#         },
#         "is_escrow_not_allowed": {
#           "type": "boolean",
#           "description": "When true, indicates that, under applicable law, a servicer may not establish an escrow account for the mortgage loan being modified."
#         },
#         "is_escrows_elected_by_borrower": {
#           "type": "boolean",
#           "description": "When true, indicates the borrower has elected to establish an escrow account."
#         },
#         "is_heloc": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan is a Home Equity Line of Credit (HELOC)."
#         },
#         "is_higher_priced_mortgage": {
#           "type": "boolean",
#           "description": "When true, indicates the transaction is considered to be a higher priced mortgage loan under Regulation Z requirements."
#         },
#         "is_home_buyers_homeownership_education_certificate": {
#           "type": "boolean",
#           "description": "Indicates whether the Home Buyers/Home Ownership Education certificate is included in the loan file."
#         },
#         "initial_fixed_period_effective_months_count": {
#           "type": "integer",
#           "description": "The number of months in the initial fixed period of a loan with an adjustable rate or payment."
#         },
#         "is_interest_credited_to_borrower": {
#           "type": "boolean",
#           "description": "Identifies whether interest was credited to the borrower at time of closing for a closed-end mortgage."
#         },
#         "is_interest_only": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan terms allow interest-only payments to be made for a specified time period."
#         },
#         "is_interest_rate_increase": {
#           "type": "boolean",
#           "description": "When true, indicates that the interest rate on the loan can increase after the closing."
#         },
#         "is_jurisdiction_high_cost": {
#           "type": "boolean",
#           "description": "When true, indicates the loan is determined to be high cost under the jurisdictions high cost rules or requirements."
#         },
#         "is_lender_placed_hazard_insurance": {
#           "type": "boolean",
#           "description": "When true, indicates that there is lender placed hazard insurance of any kind associated with this loan."
#         },
#         "is_lender_self_insured": {
#           "type": "boolean",
#           "description": "Indicates that the Lender will provide self-insurance."
#         },
#         "lending_limit": {
#           "type": "number",
#           "description": "The maximum dollar amount limit for the mortgage loan."
#         },
#         "lending_limit_type": {
#           "type": "string",
#           "description": "Specifies the criteria, guidelines or calculation used to establish the Lending Limit Amount.",
#           "enum": [
#             "Calculated",
#             "County",
#             "Investor",
#             "Other"
#           ]
#         },
#         "lending_limit_type_other": {
#           "type": "string",
#           "description": "A free-form text field used to collect additional information when Other is selected for Other is selected for the Lending Limit Type."
#         },
#         "is_lien_holder_same_as_subject": {
#           "type": "boolean",
#           "description": "Indicates that the lien holder of the related loan is the same as the lien holder of the subject loan."
#         },
#         "is_affordable": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan is classified as an affordable loan by the lender or the investor."
#         },
#         "age_months_count": {
#           "type": "integer",
#           "description": "The age of the loan expressed in months calculated as defined by trading partner agreement."
#         },
#         "is_amount_increase": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan amount can increase after closing."
#         },
#         "approval_date": {
#           "type": "string",
#           "description": "The date the mortgage loan approval was made by the lender to the borrower. A loan approval involves verifying credit, down payment, employment history, etc. of the borrower(s) and will generally state that the borrower is approved for a loan upon satisfaction of certain conditions.",
#           "format": "date"
#         },
#         "approval_expiration_date": {
#           "type": "string",
#           "description": "The date the mortgage loan approval expires.",
#           "format": "date"
#         },
#         "approval_period_days_count": {
#           "type": "integer",
#           "description": "The number of days the mortgage loan approval is in effect."
#         },
#         "is_asset_added": {
#           "type": "boolean",
#           "description": "When true, indicates that this loan asset was added to the security in the current investor reporting period."
#         },
#         "closing_status_type": {
#           "type": "string",
#           "description": "Defines whether the loan is a closed loan purchase or a table funded loan.",
#           "enum": [
#             "Closed",
#             "TableFunded"
#           ]
#         },
#         "commitment_date": {
#           "type": "string",
#           "description": "The date the mortgage loan commitment to the borrower was made. The loan commitment is a  formal, binding offer from a lender that a specified amount of loan or line of credit will be made available to the named borrower at a certain interest rate, during a certain period and, usually, for a certain purpose. The commitment also specifies the terms and requirements under which the loan will be advanced.",
#           "format": "date"
#         },
#         "commitment_expiration_date": {
#           "type": "string",
#           "description": "The date the mortgage loan commitment expires.",
#           "format": "date"
#         },
#         "commitment_period_days_count": {
#           "type": "integer",
#           "description": "The number of days the mortgage loan commitment is in effect."
#         },
#         "is_estimate_waiting_period_waived": {
#           "type": "boolean",
#           "description": "When true, indicates that upon receipt of the Loan Estimate, and due to a bona fide personal financial emergency, the consumer modified or waived the seven-business-day waiting period that must be met prior to consummation of the mortgage loan transaction."
#         },
#         "loan_role_type": {
#           "type": "string",
#           "description": "An attribute of LOAN used to identify the role the associated LOAN plays in the transaction.",
#           "enum": [
#             "HistoricalLoan",
#             "RelatedLoan",
#             "SubjectLoan"
#           ]
#         },
#         "funding_date": {
#           "type": "string",
#           "description": "The date the loan funds were released from the original lender to the closing agent for disbursement to the borrower.",
#           "format": "date"
#         },
#         "is_level_credit_score": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan level credit score was used for decisioning of the loan."
#         },
#         "repayment_type": {
#           "type": "string",
#           "description": "Specifies whether the loan payment schedule has been calculated to fully repay the loan over the mortgage term.",
#           "enum": [
#             "ConstantPrincipal",
#             "Other",
#             "PrincipalPaymentOption",
#             "ScheduledAmortization"
#           ]
#         },
#         "repayment_type_other": {
#           "type": "string",
#           "description": "A free-form text field used to collect additional information when Other is selected for Loan Repayment Type."
#         },
#         "sale_funding_date": {
#           "type": "string",
#           "description": "The date the investor releases funds to the seller of the loan.",
#           "format": "date"
#         },
#         "secured_by_type": {
#           "type": "string",
#           "description": "Specifies the type of collateral securing the loan.",
#           "enum": [
#             "Other",
#             "SubjectProperty"
#           ]
#         },
#         "secured_by_type_other": {
#           "type": "string",
#           "description": "A free-form text field used to collect additional information when Other is selected for Loan Secured By Type."
#         },
#         "is_secured": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan is secured by some type of collateral."
#         },
#         "seller_provided_investment_rating_description": {
#           "type": "string",
#           "description": "The widely-recognized alpha code (e.g., AA, A, B, etc.) provided by the seller which specifies the credit risk class of a financial asset (e.g. a loan or mortgage backed security)."
#         },
#         "is_lost_note_affidavit": {
#           "type": "boolean",
#           "description": "Indicates whether or not a lost note affidavit (LNA) is associated with the loan."
#         },
#         "is_mi_coverage_exists": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan is covered by mortgage insurance."
#         },
#         "is_mi_required": {
#           "type": "boolean",
#           "description": "Indicates that Mortgage Insurance is or was required as a condition for originating the loan."
#         },
#         "is_mortgage_modification": {
#           "type": "boolean",
#           "description": "Indicates that a loan modification exists."
#         },
#         "is_negative_amortization": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan terms allow unpaid interest to be added to the principal of the loan  that can or will result in negative amortization."
#         },
#         "is_open_end_credit": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan or the application is for an open end loan, also known as a line of credit."
#         },
#         "is_original_standard_escrow_provisions": {
#           "type": "boolean",
#           "description": "When true indicates the original loan documents included standard Fannie Mae/Freddie Mac Uniform Instrument provisions for escrow items."
#         },
#         "overdue_interest": {
#           "type": "number",
#           "description": "The dollar amount of interest accrued but not yet paid for Daily Simple Interest loans. This interest is considered overdue interest and is paid first when a payment is applied."
#         },
#         "is_payment_increase": {
#           "type": "boolean",
#           "description": "When true, indicates that the payments on the loan can increase after the closing."
#         },
#         "is_piggyback": {
#           "type": "boolean",
#           "description": "Indicates a second lien being carried under the same loan number as a first mortgage. Generally one mortgage is covered by two notes and the borrower makes one combined payment."
#         },
#         "pool_identifier": {
#           "type": "string",
#           "description": "The unique identifier for a group or pool of loans. May include relevant prefix and suffix when not parsed into applicable fields. See Pool Prefix Identifier or Pool Suffix Identifier."
#         },
#         "pool_issue_date": {
#           "type": "string",
#           "description": "The date a mortgage backed security is issued to investors.",
#           "format": "date"
#         },
#         "pool_prefix_identifier": {
#           "type": "string",
#           "description": "The prefix associated with the pool identifier."
#         },
#         "is_prepayment_penalty": {
#           "type": "boolean",
#           "description": "Indicates whether the loan includes a penalty charged to the borrower in the event of prepayment."
#         },
#         "is_prepayment_penalty_waived": {
#           "type": "boolean",
#           "description": "Indicates that the prepayment penalty has been waived."
#         },
#         "is_prepayment_restriction": {
#           "type": "boolean",
#           "description": "Indicates whether the loan has any restrictions on the prepayment of the loan (i.e. paying off the principal and or interest at a rate faster than prescribed by the payment schedule)."
#         },
#         "properties_financed_by_lender_count": {
#           "type": "integer",
#           "description": "Case or loan level count of properties already financed by this lender for the borrower(s) named on the loan application. Does not include subject property"
#         },
#         "is_property_inspection_waiver": {
#           "type": "boolean",
#           "description": "Indicates whether a documented inspection of the property has been waived."
#         },
#         "is_qualified_mortgage": {
#           "type": "boolean",
#           "description": "When true, indicates the loan is determined to be a qualified mortgage under Regulation Z requirements."
#         },
#         "recoverable_corporate_advance_balance_from_borrower": {
#           "type": "number",
#           "description": "Monies advanced on the loan (i.e. delinquency expense, tax penalty, repairs, etc.) that are recoverable from the borrower."
#         },
#         "recoverable_corporate_advance_balance_from_third_party": {
#           "type": "number",
#           "description": "Monies advanced on the loan (i.e. delinquency expense, tax penalty, repairs, etc.) that are recoverable from a third party."
#         },
#         "refund_of_overpaid_interest_calendar_year": {
#           "type": "number",
#           "description": "The amount of overpaid interest refunded to the borrower for the calendar year."
#         },
#         "is_regulation_z_high_cost": {
#           "type": "boolean",
#           "description": "When true, indicates the loan is determined to be high cost under Regulation Z."
#         },
#         "is_relocation": {
#           "type": "boolean",
#           "description": "Indicates if the loan is part of a corporate relocation program."
#         },
#         "remaining_unearned_interest": {
#           "type": "number",
#           "description": "The remaining amount of interest scheduled to be paid on a rule of 78s loan."
#         },
#         "is_renovation": {
#           "type": "boolean",
#           "description": "When true, indicates that all or part of the subject loan proceeds will be used to finance the renovation of an existing property."
#         },
#         "respa_conforming_year_type": {
#           "type": "string",
#           "description": "A value from a MISMO prescribed list that represents the version of RESPA regulation under which the loan was originated.",
#           "enum": [
#             "January2010",
#             "October2015",
#             "Other",
#             "Pre2010"
#           ]
#         },
#         "respa_conforming_year_type_other": {
#           "type": "string",
#           "description": "A free-form text field that specifies the enumeration when the value of Other is used for the RESPA Conforming Year Type."
#         },
#         "is_reverse_mortgage": {
#           "type": "boolean",
#           "description": "When true, indicates the loan program uses present equity in the property to fund payments from the lender to the borrower-in lieu of the borrower receiving the proceeds of the loan in a lump sum. As a general rule no payments are made from the borrower to the lender and interest is accrued for payment at the end of the mortgage."
#         },
#         "is_right_of_rescission_waiting_period_waived": {
#           "type": "boolean",
#           "description": "When true, indicates that due to a bona fide personal financial emergency, the consumer modified or waived the right to rescind waiting period requirement that must be met prior to consummation of the mortgage loan transaction."
#         },
#         "is_scra": {
#           "type": "boolean",
#           "description": "When true, indicates that the loan is subject to the Servicemembers Civil Relief Act (SCRA)."
#         },
#         "is_scra_relief_forbearance_requested": {
#           "type": "boolean",
#           "description": "When true indicates that relief under Servicemembers Civil Relief Act (SCRA) has been requested."
#         },
#         "scra_relief_status_type": {
#           "type": "string",
#           "description": "Specifies the status of relief under the Servicemembers Civil Relief Act (SCRA) for any borrower on the loan.",
#           "enum": [
#             "NeverReceived",
#             "OneOrMoreBorrowersCurrentlyReceive",
#             "OneOrMoreBorrowersPreviouslyReceived",
#             "Other"
#           ]
#         },
#         "scra_relief_status_type_other": {
#           "type": "string",
#           "description": "A free-form text field used to collect additional information when Other is selected as the Servicemember Relief Status Type."
#         },
#         "seasonal_payment_feature_description": {
#           "type": "string",
#           "description": "Specifies the details of the seasonal payment feature, including the period during which periodic payments are not scheduled."
#         },
#         "is_seasonal_payment_feature": {
#           "type": "boolean",
#           "description": "When true, indicates the loan contains a seasonal payment feature."
#         },
#         "is_servicing_transfer_prohibited": {
#           "type": "boolean",
#           "description": "When true, indicates that the transfer of servicing is prohibited during life of the loan or for a designated period of time or until a certain event or condition is satisfied."
#         },
#         "servicing_transfer_status_type": {
#           "type": "string",
#           "description": "Defines whether the servicing on the loan will be retained or transferred to another party. Typically only on closed loans.",
#           "enum": [
#             "Released",
#             "Retained"
#           ]
#         },
#         "is_shared_appreciation": {
#           "type": "boolean",
# ...
#         }
#       }
#     },
#     "mi_products_extra": {
#       "type": "object",
#       "properties": {
#         "mi_premium_taxes": {
#           "$ref": "#/definitions/mi_premium_taxes"
#         },
#         "mi_premiums": {
#           "$ref": "#/definitions/mi_premiums",
#           "description": "Information regarding one or more types of mortgage insurance premiums. Holds all occurrences of MI_PREMIUM"
#         }
#       }
#     },
#     "modifications_extra": {
#       "type": "object",
#       "properties": {
#         "life_of_loan_total_forgiven_interest": {
#           "type": "number",
#           "description": "Cumulative total amount of interest forgiven over the life of the loan."
#         },
#         "life_of_loan_total_forgiven_principal": {
#           "type": "number",
#           "description": "Cumulative total amount of principal forgiven over the life of the loan."
#         }
#       }
#     },
#     "optional_products_extra": {
#       "type": "object",
#       "properties": {
#         "premiums_total": {
#           "type": "number",
#           "description": "The sum of all Optional Product Premium Amounts for all selected Optional Product Plan Types."
#         }
#       }
#     },
#     "present_land_uses_extra": {
#       "type": "object",
#       "properties": {
#         "neighborhood_change_status_type": {
#           "type": "string",
#           "description": "Specifies whether the land use in the neighborhood is not likely, likely or in the process of changing.",
#           "enum": [
#             "InProcess",
#             "Likely",
#             "NotLikely"
#           ]
#         },
#         "neighborhood_current_description": {
#           "type": "string",
#           "description": "A free-form text field used to describe the existing land use in the neighborhood."
#         },
#         "neighborhood_future_description": {
#           "type": "string",
#           "description": "A free-form text field used to describe what the future land use will be in the neighborhood."
#         }
#       }
#     },
#     "purchase_credits_extra": {
#       "type": "object",
#       "properties": {
#         "total": {
#           "type": "number",
#           "description": "The total amount of all fees required to be remitted to the county recorder for recording a single document. (Depending on state laws and local ordinances there may not be a direct relationship between Recording Endorsement Fees and RESPA Fees.)"
#         }
#       }
#     },
#     "recording_endorsement_exemptions_extra": {
#       "type": "object",
#       "properties": {
#         "total": {
#           "type": "number",
#           "description": "The total amount of all fees required to be remitted to the county recorder for recording a single document. (Depending on state laws and local ordinances there may not be a direct relationship between Recording Endorsement Fees and RESPA Fees.)"
#         }
#       }
#     },
#     "recording_endorsement_fees_extra": {
#       "type": "object",
#       "properties": {
#         "total": {
#           "type": "number",
#           "description": "The total amount of all fees required to be remitted to the county recorder for recording a single document. (Depending on state laws and local ordinances there may not be a direct relationship between Recording Endorsement Fees and RESPA Fees.)"
#         }
#       }
#     },
#     "workouts_extra": {
#       "type": "object",
#       "properties": {
#         "life_of_loan_borrower_assistance_paid": {
#           "type": "number",
#           "description": "The total dollar amount of all borrower assistance paid to the servicer on behalf of the borrower associated with any workouts over the life of the loan. Repayment of funds is not expected."
#         },
#         "life_of_loan_modification_count": {
#           "type": "integer",
#           "description": "A count of the number of prior completed modifications associated with workouts over the life of the loan."
#         },
#         "life_of_loan_modification_defaulted_count": {
#           "type": "integer",
#           "description": "A count of the number of prior completed modifications where the loan subsequently missed two or more payments."
#         }
#       }
#     },
#     "pages": {
#       "type": "object",
#       "description": "A collection of page elements that are part of a document.",
#       "properties": {
#         "page": {
#           "type": "array",
#           "items": {
#             "$ref": "#/definitions/page"
#           }
#         }
#       }
#     },
#     "page": {
#       "type": "object",
#       "properties": {
#         "identifier": {
#           "type": "string",
#           "description": "Identifier of the pages in document"
#         }
#       }
#     },
#     "verification_of_assets_request": {
#       "type": "object",
#       "description": "This container holds data specific to requesting an asset verification service.",
#       "properties": {
#         "days_of_data_requested": {
#           "type": "number",
#           "description": "The requested number of days of asset verification."
#         },
#         "partner": {
#           "type": "string",
#           "description": "The partner used for the asset verification."
#         },
#         "partner_product": {
#           "type": "string",
#           "description": "The partner's product name used for the asset verification."
#         },
#         "service_date": {
#           "type": "string",
#           "description": "The date of the verification request.",
#           "format": "date"
#         }
#       }
#     },
#     "verification_of_assets_response": {
#       "type": "object",
#       "description": "This container holds data specific to response associated with the asset verification service requested.",
#       "properties": {
#         "partner": {
#           "type": "string",
#           "description": "The partner used for the asset verification."
#         },
#         "partner_data_source_account_id": {
#           "type": "string",
#           "description": "The partner's identifier of the individual that is the subject (ie, the borrower) of the asset verification."
#         },
#         "partner_data_source_date": {
#           "type": "string",
#           "description": "The partner's as of date of the data source used for the asset verification.",
#           "format": "date"
#         },
#         "partner_data_source_id": {
#           "type": "string",
#           "description": "The partner's identifier of the data source used for the asset verification."
#         },
#         "partner_product": {
#           "type": "string",
#           "description": "The partner's product name used for the asset verification."
#         },
#         "service_date": {
#           "type": "string",
#           "description": "The date of the asset verification.",
#           "format": "date"
#         }
#       },
#       "required": []
#     },
#     "verification_of_assets": {
#       "type": "object",
#       "description": "This container holds other containers, data points and data specific to asset verification services.",
#       "properties": {
#         "verification_of_assets_request": {
#           "$ref": "#/definitions/verification_of_assets_request"
#         },
#         "verification_of_assets_response": {
#           "$ref": "#/definitions/verification_of_assets_response"
#         }
#       }
#     },
#     "verification_of_employment_request": {
#       "type": "object",
#       "description": "This container holds data specific to requesting an employment verification service.",
#       "properties": {
#         "partner": {
#           "type": "string",
#           "description": "The partner used for the employment verification."
#         },
#         "partner_product": {
#           "type": "string",
#           "description": "The partner's product name used for the employment verification."
#         },
#         "service_date": {
#           "type": "string",
#           "description": "The date of the verification request.",
#           "format": "date"
#         }
#       },
#       "required": []
#     },
#     "verification_of_employment_response": {
#       "type": "object",
#       "description": "This container holds data specific to response associated with the employment verification service requested.",
#       "properties": {
#         "partner": {
#           "type": "string",
#           "description": "The partner used for the employment verification."
#         },
#         "partner_data_source_account_id": {
#           "type": "string",
#           "description": "The partner's identifier of the individual that is the subject (ie, the borrower) of the employment verification."
#         },
#         "partner_data_source_date": {
#           "type": "string",
#           "description": "The partner's as of date of the data source used for the employment verification.",
#           "format": "date"
#         },
#         "partner_data_source_id": {
#           "type": "string",
#           "description": "The partner's identifier of the data source used for the employment verification."
#         },
#         "partner_product": {
#           "type": "string",
#           "description": "The partner's product name used for the employment verification."
#         },
#         "service_date": {
#           "type": "string",
#           "description": "The date of the employment verification.",
#           "format": "date"
#         }
#       },
#       "required": []
#     },
#     "verification_of_employment": {
#       "type": "object",
#       "description": "This container holds other containers, data points and data specific to employment verification services.",
#       "properties": {
#         "verification_of_employment_request": {
#           "$ref": "#/definitions/verification_of_employment_request"
#         },
#         "verification_of_employment_response": {
#           "$ref": "#/definitions/verification_of_employment_response"
#         }
#       }
#     },
#     "lpa_document_preparation": {
#       "type": "object",
#       "description": "Contains information to request, receive and deliver prepared documents.  Specific to FreddieMac's Loan Product Advisor AUS.",
#       "properties": {
#         "lpa_document_preparation_requests": {
#           "type": "object",
#           "description": "Contains information relevent to the response to a request for document preparation.  Specific to FreddieMac's Loan Product Advisor AUS.",
#           "properties": {
#             "lpa_document_preparation_request": {
#               "type": "array",
#               "items": {
#                 "$ref": "#/definitions/lpa_document_preparation_request"
#               }
#             }
#           },
#           "required": []
#         },
#         "lpa_document_preparation_responses": {
#           "type": "object",
#           "description": "Contains information relevent to the response to a request for document preparation.  Specific to FreddieMac's Loan Product Advisor AUS.",
#           "properties": {
#             "lpa_document_preparation_response": {
#               "type": "array",
#               "items": {
#                 "$ref": "#/definitions/lpa_document_preparation_response"
#               }
#             }
#           }
#         }
#       },
#       "required": []
#     },
#     "lpa_document_preparation_request": {
#       "type": "object",
#       "description": "Contains information relevent to a request for document preparation.  Specific to FreddieMac's Loan Product Advisor AUS.",
#       "properties": {
#         "requested_document_identifier": {
#           "type": "string",
#           "description": "A unique alphanumeric string identifying the assessment report."
#         },
#         "requested_document_vendor_identifier": {
#           "type": "string",
#           "description": "A unique alphanumeric string identifying the assessment vendor."
#         }
#       }
#     },
#     "lpa_document_preparation_response": {
#       "type": "object",
#       "description": "Contains information relevant to the response to a request for document preparation.  Specific to FreddieMac's Loan Product Advisor AUS.",
#       "properties": {
#         "requested_document_type": {
#           "type": "string",
#           "description": "A value from a Freddie Mac prescribed list that identifies the document for the service or product being requested.",
#           "enum": [
#             "Errors",
#             "MergedCredit",
#             "DocCheckList",
#             "FullFeedback",
#             "HVE",
#             "CreditInfile"
#           ]
#         },
#         "is_requested_pdf": {
#           "type": "boolean",
#           "description": "When true, a PDF file of the associated RequestedDocumentType is requested."
#         },
#         "is_requested_xml": {
#           "type": "boolean",
#           "description": "When true, an embedded XML file of the associated merged credit report is requested."
#         }
#       }
#     },
#     "current_income_item_payment": {
#       "type": "object",
#       "description": "A payment that represents income, for example, a paycheck",
#       "properties": {
#         "other_period_description": {
#           "type": "string",
#           "description": "Amount of income payment, used to specify income payments for time periods other than the standard monthly."
#         },
#         "other_period_total": {
#           "type": "number",
#           "description": "The period of time for which the income payment covers (other than monthly)."
#         },
#         "type": {
#           "type": "string",
#           "description": "The type of income payment",
#           "enum": [
#             "AccessoryUnitIincome",
#             "Alimony",
#             "AutomobileAllowance",
#             "Base",
#             "BoarderIncome",
#             "Bonus",
#             "BorrowerEstimatedTotalMonthlyIncome",
#             "CapitalGains",
#             "ChildSupport",
#             "Commissions",
#             "ContractBasis",
#             "DefinedContributionPlan",
#             "Disability",
#             "DividendsInterest",
#             "EmploymentRelatedAccount",
#             "FosterCare",
#             "HousingAllowance",
#             "HousingChoiceVoucherProgram",
#             "MilitaryBasePay",
#             "MilitaryClothesAllowance",
#             "MilitaryCombatPay",
#             "MilitaryFlightPay",
#             "MilitaryHazardPay",
#             "MilitaryOverseasPay",
#             "MilitaryPropPay",
#             "MilitaryQuartersAllowance",
#             "MilitaryRationsAllowance",
#             "MilitaryVariableHousingAllowance",
#             "MiscellaneousIncome",
#             "MortgageCreditCertificate",
#             "MortgageDifferential",
#             "NetRentalIncome",
#             "NetLongTermCapitalGainOrLoss",
#             "NetShortTermCapitalGainOrLoss",
#             "NonBorrowerContribution",
#             "NonBorrowerHouseholdIncome",
#             "NotesReceivableInstallment",
#             "Other",
#             "Overtime",
#             "Pension",
#             "ProposedGrossRentForSubjectProperty",
#             "PublicAssistance",
#             "RealEstateOwnedGrossRentalIncome",
#             "Royalties",
#             "SelfEmploymentIncome",
#             "SelfEmploymentLoss",
#             "SeparateMaintenance",
#             "SocialSecurity",
#             "SubjectPropertyNetCashFlow",
#             "TemporaryLeave",
#             "TipIncome",
#             "TrailingCoBorrowerIncome",
#             "Trust",
#             "Unemployment",
#             "VABenefitsNonEducational",
#             "WorkersCompensation",
#             "NonTaxableInterestIncome",
#             "TaxableDividendsIncome",
#             "BusinessIncome",
#             "current_income"
#           ]
#         }
#       }
#     },
#     "current_income_item_payments": {
#       "type": "object",
#       "description": "A payment that represents income, like a paycheck",
#       "properties": {
#         "current_income_item_payment": {
#           "type": "array",
#           "items": {
#             "$ref": "#/definitions/current_income_item_payment"
#           }
#         }
#       },
#       "required": []
#     },
#     "relationship_id": {
#       "type": "string",
#       "description": "A string describing a relationship between objects in the loan"
#     },
#     "array_sequence_number": {
#       "type": "string",
#       "description": "The number of the element in an array"
#     }
#   }
# }
